# %%
print("hello")
# Out:
# hello

# %%
from googleapiclient.discovery import build
import pymongo
import pymysql
import pandas as pd
from datetime import datetime
import numpy as np
import datetime
import re
import mysql.connector

# %%
def API_connection():
    api="AIzaSyA-jIa8FxWSU6gegC-IASOCWvf8Fo1I5kY"

    api_service_name = "youtube"
    api_version = "v3"

    youtube=build(api_service_name,api_version,developerKey=api)

    return youtube

youtube=API_connection()

# %%
def get_channel_info(CHID):
        Request=youtube.channels().list(
                part="snippet,contentDetails,statistics",
                id=CHID
        )

        response=Request.execute()

        for i in response['items']:
                data=dict(channel_Name=i["snippet"]["title"],
                        channel_id=i["id"],
                        Subscribres=i["statistics"]["subscriberCount"],
                        Total_Videos=i["statistics"]["videoCount"],
                        Total_Views=i["statistics"]["viewCount"],
                        Channel_Description=i["snippet"]["description"],
                        playlist_ID=i["contentDetails"]["relatedPlaylists"],
                         )
                return data

# %%
Chn_details=get_channel_info("UCD4fBiLu_tbf_XH73Pp9vxQ")

# %%
Chn_details
# Out:
# {'channel_Name': 'kamalsharmi💕',
#  'channel_id': 'UCD4fBiLu_tbf_XH73Pp9vxQ',
#  'Subscribres': '301',
#  'Total_Videos': '46',
#  'Total_Views': '79395',
#  'Channel_Description': 'Subscribe the channel🙏😊',
#  'playlist_ID': {'likes': '', 'uploads': 'UUD4fBiLu_tbf_XH73Pp9vxQ'}}

# %%
def get_videos_id(Channel_ID):
        Videos_ID=[]
        next_Page=None
        while True:


                request = youtube.playlistItems().list(
                        part="contentDetails",
                        maxResults=50,
                        playlistId=Chn_details["playlist_ID"]["uploads"],
                        pageToken=next_Page

                        )
                response = request.execute()

                print(response)

                for i in range(len(response['items'])):


                        Videos_ID.append (response['items'][i]["contentDetails"]["videoId"])


                next_Page = response.get("nextPageToken")
                if next_Page is None:
                        break
        return Videos_ID


Video_ids=get_videos_id("Chn_ID")
# Out:
# {'kind': 'youtube#playlistItemListResponse', 'etag': 'yaDIuQyhE4Ja-r-O4vy8R5scnDo', 'items': [{'kind': 'youtube#playlistItem', 'etag': 'I8-ah3nTfoYnb7ZhI23mAUp5Qus', 'id': 'VVVENGZCaUx1X3RiZl9YSDczUHA5dnhRLkpYT19HSEJObm1J', 'contentDetails': {'videoId': 'JXO_GHBNnmI', 'videoPublishedAt': '2024-02-12T02:19:59Z'}}, {'kind': 'youtube#playlistItem', 'etag': '3-_v0mqycO3UzoVI0518yZ_01VE', 'id': 'VVVENGZCaUx1X3RiZl9YSDczUHA5dnhRLmdxVVp0azh3Sjln', 'contentDetails': {'videoId': 'gqUZtk8wJ9g', 'videoPublishedAt': '2024-02-04T09:14:18Z'}}, {'kind': 'youtube#playlistItem', 'etag': '9m1wCMHBi-m0wM5eMKBto3ViLG0', 'id': 'VVVENGZCaUx1X3RiZl9YSDczUHA5dnhRLjd1WFRiaG5DbnpJ', 'contentDetails': {'videoId': '7uXTbhnCnzI', 'videoPublishedAt': '2023-11-09T14:18:54Z'}}, {'kind': 'youtube#playlistItem', 'etag': 'vxghytSx3WrMCUgR3DpmCp9XngQ', 'id': 'VVVENGZCaUx1X3RiZl9YSDczUHA5dnhRLlZ4NlY1bUxidmRj', 'contentDetails': {'videoId': 'Vx6V5mLbvdc', 'videoPublishedAt': '2023-11-03T13:22:50Z'}}, {'kind': 'youtube#pl
# ...

# %%
Video_ids
# Out:
# ['JXO_GHBNnmI',
#  'gqUZtk8wJ9g',
#  '7uXTbhnCnzI',
#  'Vx6V5mLbvdc',
#  'Oq1YC4O3Jwg',
#  'iqVA-VBMids',
#  'wn9Ohtr_WJs',
#  'tz_X3yyMPoQ',
#  'BhKpfC1z2sk',
#  'xO6BWiaDHUg',
#  '7P9XJMsLG8A',
#  'AEXY432fbeA',
#  'q8laltpuHeE',
#  'm2Y3UbnhEPY',
#  'Y-86AGRgFGw',
#  'UUZKZlVFK64',
#  'psvtapbC00E',
#  'PgAuSFQ2CuQ',
#  'kHBRnaEVuts',
#  '777eRLz-3OU',
#  'wQhZ3rTCqXk',
#  '3O8hc9_aIz0',
#  'fTLsllvqgUQ',
#  'axoM96p6NNw',
#  'cXTF0WG2Sok',
#  'ijJey8QwbsI',
#  'XIk0LNP37PE',
#  '6LpOGlUZCZo',
#  '3gU5mUv784k',
#  'YsR12rc1wNE',
#  'ywAOnJjp188',
#  'xRv7ORrBI-U',
#  'ycoZmtNDtic',
#  'szF-CveOWSk',
#  'Gzz18hNAMqM',
#  'hu-KygayWRs',
#  '9FDD1pF0h6U',
#  'jFKyalue4-c',
#  '9WCSph7Dgag',
#  '8yaWLqJwyWM',
#  'MJBdKKj0qMQ',
#  'aWLK7kVM79k',
#  'hsaxm8uiSow',
#  'XM53IcfuH08',
#  'woH3hWJIWy4',
#  'g59-s0gfpoo']

# %%
def get_Video_info(Video_ids):
        Video_data=[]
        for video_ID in Video_ids:
                request = youtube.videos().list(
                                part="snippet,contentDetails,statistics",
                                id=video_ID
                        )

                response = request.execute()
                print(response)

                for item in response ["items"]:
                        data=dict(Channel_Name=item["snippet"]["channelTitle"],
                        Channenl_ID=item["snippet"]["channelId"],
                        Video_ID=item["id"],
                        Title=item["snippet"]["title"],
                        Thumbnails=item["snippet"]["thumbnails"]["default"]['url'],
                        Description=item["snippet"]["description"],
                        Published=item["snippet"]["publishedAt"],
                        Duration=item["contentDetails"]["duration"],
                        Views=item["statistics"].get("viewCount"),
                        Likes=item["statistics"].get("likeCount"),
                        comments=item["statistics"].get("commentCount"),
                        Favorite_Count=item["statistics"]["favoriteCount"],
                        Defination=item["contentDetails"]["definition"],
                        caption_status=item["contentDetails"]["caption"],
                        Tags=item["snippet"].get("tags")

                        )

                Video_data.append(data)

        return Video_data

# %%
Video_information=get_Video_info(Video_ids)
# Out:
# {'kind': 'youtube#videoListResponse', 'etag': 'YIFd4a66DuU23-83QTogZe0SCnw', 'items': [{'kind': 'youtube#video', 'etag': 'Mi_gsnQSdqZm4mn9lfjkJwq9e7E', 'id': 'JXO_GHBNnmI', 'snippet': {'publishedAt': '2024-02-12T02:19:59Z', 'channelId': 'UCD4fBiLu_tbf_XH73Pp9vxQ', 'title': '💕🖇👼 #trendingreels #shorts #shortvideo #viral #reels #coupleshorts #tea #snacksrecipe #foodie #love', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JXO_GHBNnmI/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/JXO_GHBNnmI/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/JXO_GHBNnmI/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/JXO_GHBNnmI/sddefault.jpg', 'width': 640, 'height': 480}}, 'channelTitle': 'kamalsharmi💕', 'categoryId': '24', 'liveBroadcastContent': 'none', 'localized': {'title': '💕🖇👼 #trendingreels #shorts #shortvideo #viral #reels #coupleshorts #tea #snacksr
# ...

# %%
Video_information
# Out:
# [{'Channel_Name': 'kamalsharmi💕',
#   'Channenl_ID': 'UCD4fBiLu_tbf_XH73Pp9vxQ',
#   'Video_ID': 'JXO_GHBNnmI',
#   'Title': '💕🖇👼 #trendingreels #shorts #shortvideo #viral #reels #coupleshorts #tea #snacksrecipe #foodie #love',
#   'Thumbnails': 'https://i.ytimg.com/vi/JXO_GHBNnmI/default.jpg',
#   'Description': '',
#   'Published': '2024-02-12T02:19:59Z',
#   'Duration': 'PT15S',
#   'Views': '4',
#   'Likes': '2',
#   'comments': '0',
#   'Favorite_Count': '0',
#   'Defination': 'hd',
#   'caption_status': 'false',
#   'Tags': None},
#  {'Channel_Name': 'kamalsharmi💕',
#   'Channenl_ID': 'UCD4fBiLu_tbf_XH73Pp9vxQ',
#   'Video_ID': 'gqUZtk8wJ9g',
#   'Title': 'Annan valiyil🐍😹 #shorts #trendingshorts #shortvideo #viral #trendingshorts #vishal #food #fun',
#   'Thumbnails': 'https://i.ytimg.com/vi/gqUZtk8wJ9g/default.jpg',
#   'Description': '',
#   'Published': '2024-02-04T09:14:18Z',
#   'Duration': 'PT13S',
#   'Views': '5949',
#   'Likes': '85',
#   'comments': '2',
# ...

# %%
def get_comments(Video_information):
        Comment_data=[]
        try:
                for video_ID in Video_ids:
                        request = youtube.commentThreads().list(
                        part="snippet",
                        videoId=video_ID,
                        maxResults=50
                         )
                        response = request.execute()



                        for item in response ["items"]:
                                data=dict(comment_Id=item["snippet"]["topLevelComment"]["id"],
                                        Video_ID=item["snippet"]["topLevelComment"]["snippet"]["videoId"],
                                        Comment_Text=item["snippet"]["topLevelComment"]["snippet"]["textDisplay"],
                                        comment_Author_Name=item["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"],
                                        comment_publish_time=item["snippet"]["topLevelComment"]["snippet"]["publishedAt"]
                                        )
                                Comment_data.append(data)

        except:
                pass
    

        return Comment_data

# %%
Comment_Information=get_comments(Video_ids)

# %%
Comment_Information
# Out:
# [{'comment_Id': 'UgzjOs2OUA4q-aHTAp14AaABAg',
#   'Video_ID': 'gqUZtk8wJ9g',
#   'Comment_Text': '😅😅😅😅😂😂😂😂',
#   'comment_Author_Name': '@r.rameshr5315',
#   'comment_publish_time': '2024-02-04T21:09:29Z'},
#  {'comment_Id': 'UgwIt82-OBI94Qsdw6F4AaABAg',
#   'Video_ID': 'gqUZtk8wJ9g',
#   'Comment_Text': '😅😅',
#   'comment_Author_Name': '@yasirarabath686',
#   'comment_publish_time': '2024-02-04T13:15:46Z'},
#  {'comment_Id': 'UgxcXHkODRSPXQC2Kc54AaABAg',
#   'Video_ID': 'xO6BWiaDHUg',
#   'Comment_Text': '😂😂',
#   'comment_Author_Name': '@SatishKumar-xf1xb',
#   'comment_publish_time': '2023-08-04T13:02:48Z'},
#  {'comment_Id': 'UgzMPdWa-F5cUdkwn-h4AaABAg',
#   'Video_ID': '7P9XJMsLG8A',
#   'Comment_Text': 'Learn Hindi too bro 😂for safety purpose',
#   'comment_Author_Name': '@SatishKumar-xf1xb',
#   'comment_publish_time': '2023-08-01T04:13:40Z'}]

# %%
#kamalsharmi1013 : "UCD4fBiLu_tbf_XH73Pp9vxQ"
#TOP Songs: "UCd80n2hWMUchHMYOCcSHQIQ"
#₹INR A 2 Z:"UCkB9JA_TRO69g6PAgzIX_hA"
#Accenture:"UCvDOfCgmS7q4OYMKVpy5Xjw"
#abroad job in gulf:"UCub1ggJ2a-GG9Nv9XpAMT9A"
#UCW2EddVTNqzfUSFUbJ1blDA

# %%
#transfer data to MongoDB

client=pymongo.MongoClient("mongodb://localhost:27017")
db = client['youtube_data']

# %%
def Channel_details(Channel_ID):
    Channel_details=get_channel_info(Channel_ID)
    Video_ID=get_videos_id(Channel_ID)
    Vid_Details=get_Video_info(Video_ID)
    Cmnt_details=get_comments(Video_ID)

    Collection1=db["Channel_details"]
    Collection1.insert_one({"channel_information":Channel_details,
                            "Video_information":Vid_Details,"Comment_Information":Cmnt_details})

    return "upload Successfully"

# %%
Upload=Channel_details("UCD4fBiLu_tbf_XH73Pp9vxQ")
# Out:
# {'kind': 'youtube#playlistItemListResponse', 'etag': 'yaDIuQyhE4Ja-r-O4vy8R5scnDo', 'items': [{'kind': 'youtube#playlistItem', 'etag': 'I8-ah3nTfoYnb7ZhI23mAUp5Qus', 'id': 'VVVENGZCaUx1X3RiZl9YSDczUHA5dnhRLkpYT19HSEJObm1J', 'contentDetails': {'videoId': 'JXO_GHBNnmI', 'videoPublishedAt': '2024-02-12T02:19:59Z'}}, {'kind': 'youtube#playlistItem', 'etag': '3-_v0mqycO3UzoVI0518yZ_01VE', 'id': 'VVVENGZCaUx1X3RiZl9YSDczUHA5dnhRLmdxVVp0azh3Sjln', 'contentDetails': {'videoId': 'gqUZtk8wJ9g', 'videoPublishedAt': '2024-02-04T09:14:18Z'}}, {'kind': 'youtube#playlistItem', 'etag': '9m1wCMHBi-m0wM5eMKBto3ViLG0', 'id': 'VVVENGZCaUx1X3RiZl9YSDczUHA5dnhRLjd1WFRiaG5DbnpJ', 'contentDetails': {'videoId': '7uXTbhnCnzI', 'videoPublishedAt': '2023-11-09T14:18:54Z'}}, {'kind': 'youtube#playlistItem', 'etag': 'vxghytSx3WrMCUgR3DpmCp9XngQ', 'id': 'VVVENGZCaUx1X3RiZl9YSDczUHA5dnhRLlZ4NlY1bUxidmRj', 'contentDetails': {'videoId': 'Vx6V5mLbvdc', 'videoPublishedAt': '2023-11-03T13:22:50Z'}}, {'kind': 'youtube#pl
# ...

# %%
chn_list=[]
db=client["youtube_data"]
Collection1=db["Channel_details"]
for chn_data in Collection1.find({},{"_id":0,"channel_information":1}):
            chn_list.append(chn_data["channel_information"])

df=pd.DataFrame(chn_list)

for index, row in df.iterrows():
            insert_query = '''INSERT INTO channel (channel_Name, channel_id, Subscribres, Total_Videos, Total_Views, Channel_Description)
                            VALUES (%s, %s, %s, %s, %s, %s)'''
            values = (row["channel_Name"], row["channel_id"], row["Subscribres"], row["Total_Videos"], row["Total_Views"], row["Channel_Description"])

            mycursor.execute(insert_query, values)
            mydb.commit()

print("Channels value  inserted")
# Out:
# Channels value  inserted

# %%
#video table
mydb = pymysql.connect(
            user='root',
            host='127.0.0.1',
            password="shanmugam",
            port=3306,
            database='youtube_data'
        )


mycursor=mydb.cursor()


query = '''create table IF NOT EXISTS videos1 (Channel_Name VARCHAR(100), Channenl_ID VARCHAR(100), Video_ID VARCHAR(100), Title text, Thumbnails VARCHAR(255), Description text, Published TIMESTAMP, Duration varchar(100), Views bigint, Likes bigint, comments bigint, Favorite_Count int, Defination varchar(10), caption_status varchar(50), Tags text)
           '''



mycursor.execute(query)

mydb.commit()


print("Video table created")
# Out:
# Video table created

# %%
video_list=[]
db=client["youtube_data"]
Collection1=db["Channel_details"]
for vid_data in Collection1.find({},{"_id":0,"Video_information":1}):
            for i in range(len(vid_data["Video_information"])):
                video_list.append(vid_data["Video_information"][i])

df1=pd.DataFrame(video_list)







for index, row in df1.iterrows():

    published_date = re.search(r'\d{4}-\d{2}-\d{2}', row["Published"]).group()
   

 
    insert_query = '''INSERT INTO videos1 (Channel_Name, 
                                      Channenl_ID,  
                                      Video_ID,
                                      Title,
                                      Thumbnails,
                                      Description,
                                      Published,
                                      Duration,
                                      Views,
                                      Likes,
                                      comments,
                                      Favorite_Count,
                                      Defination,
                                      caption_status,
                                      Tags)
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''
    
    VALUES = (row["Channel_Name"], row["Channenl_ID"], row["Video_ID"], row["Title"], row["Thumbnails"], row["Description"], published_date, row["Duration"], row["Views"], row["Likes"], row["comments"], row["Favorite_Count"], row["Defination"], row["caption_status"], row["Tags"])

    mycursor.execute(insert_query, VALUES)
    mydb.commit()

print("video information value inserted")
# Out:
# video information value inserted

# %%
#comments, table

mydb = pymysql.connect(
            user='root',
            host='127.0.0.1',
            password="shanmugam",
            port=3306,
            database='youtube_data'
        )


mycursor=mydb.cursor()


query = '''create table IF NOT EXISTS comments (comment_Id VARCHAR(100), Video_ID VARCHAR(100), Comment_Text text, comment_Author_Name VARCHAR(150), comment_publish_time timestamp)'''
           



mycursor.execute(query)

mydb.commit()


print("comment table created")
# Out:
# comment table created

# %%
comnt_list=[]
db=client["youtube_data"]
Collection1=db["Channel_details"]
for comnt_data in Collection1.find({},{"_id":0,"Comment_details":1}):
            comnt_list.append(comnt_data["Comment_details"])

df2=pd.DataFrame(comnt_data["Comment_details"])

for index, row in df2.iterrows():

    published_date = re.search(r'\d{4}-\d{2}-\d{2}', row["comment_publish_time"]).group()

    insert_query = '''INSERT INTO comments (comment_Id, Video_ID, Comment_Text, comment_Author_Name, comment_publish_time)
                            VALUES (%s, %s, %s, %s, %s)'''
    values = (row["comment_Id"], row["Video_ID"], row["Comment_Text"], row["comment_Author_Name"], published_date)

    mycursor.execute(insert_query, values)
    mydb.commit()

print("Comments value  inserted")
# Out:
# Comments value  inserted

# %%
df2
# Out:
#                    comment_Id     Video_ID  \
# 0  UgzjOs2OUA4q-aHTAp14AaABAg  gqUZtk8wJ9g
# 1  UgwIt82-OBI94Qsdw6F4AaABAg  gqUZtk8wJ9g
# 2  UgxcXHkODRSPXQC2Kc54AaABAg  xO6BWiaDHUg
# 3  UgzMPdWa-F5cUdkwn-h4AaABAg  7P9XJMsLG8A
#
#                               Comment_Text comment_Author_Name  \
# 0                                 😅😅😅😅😂😂😂😂      @r.rameshr5315
# 1                                       😅😅    @yasirarabath686
# 2                                       😂😂  @SatishKumar-xf1xb
# 3  Learn Hindi too bro 😂for safety purpose  @SatishKumar-xf1xb
#
#    comment_publish_time
# 0  2024-02-04T21:09:29Z
# 1  2024-02-04T13:15:46Z
# 2  2023-08-04T13:02:48Z
# 3  2023-08-01T04:13:40Z

# %%
mydb = pymysql.connect(
            user='root',
            host='127.0.0.1',
            password="shanmugam",
            port=3306,
            database='youtube_data'
        )


mycursor=mydb.cursor()


query = '''create table if not exists channel (channel_Name VARCHAR(100), channel_id VARCHAR(100), Subscribres bigint, Total_Videos bigint, Total_Views bigint, Channel_Description text)
           '''





mycursor.execute(query)

mydb.commit()


print("channel table created")

CHID="UCD4fBiLu_tbf_XH73Pp9vxQ"
Collection1=db["Channel_details"]
data = Collection1.find_one({"channel_information.channel_id":CHID})
print(data.keys())


channel_df=pd.DataFrame(data["channel_information"],index=[0])      

video_df =pd.DataFrame(data["Video_information"])

comment_df =pd.DataFrame(data["Comment_Information"])

insert_query=''' insert into channel(channel_Name,
                                    channel_id,
                                    Subscribres,
                                    Total_Videos,
                                    Total_Views,
                                    Channel_Description)
                                    
                                    values(%s,%s,%s,%s,%s,%s)'''

values=tuple(data["channel_information"].values())

mycursor.execute(insert_query,values)
mydb.commit()



query = '''create table if not exists videos (Channel_Name VARCHAR(100), Channenl_ID VARCHAR(100), Video_ID VARCHAR(100), Title text, Thumbnails VARCHAR(255), Description text, Published TIMESTAMP, Duration varchar(100), Views bigint, Likes bigint, comments bigint, Favorite_Count int, Defination varchar(10), caption_status varchar(50), Tags text)'''

mycursor.execute(query)

mydb.commit()


print("Video table created")

data = Collection1.find_one({"Video_information.channel_id":CHID})


insert_query = '''INSERT INTO videos (Channel_Name, 
                                      Channenl_ID,  
                                      Video_ID,
                                      Title,
                                      Thumbnails,
                                      Description,
                                      Published,
                                      Duration,
                                      Views,
                                      Likes,
                                      comments,
                                      Favorite_Count,
                                      Defination,
                                      caption_status,
                                      Tags)
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''

values=tuple(data["Video_information"].values())

mycursor.execute(insert_query,values)
mydb.commit()
# Out:
# channel table created
# dict_keys(['_id', 'channel_information', 'Video_information', 'Comment_Information'])
# Video table created
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 84
#      64 data = Collection1.find_one({"Video_information.channel_id":CHID})
#      67 insert_query = '''INSERT INTO videos (Channel_Name,
#      68                                       Channenl_ID,
#      69                                       Video_ID,
#    (...)
#      81                                       Tags)
#      82                 VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''
# ---> 84 values=tuple(data["Video_information"].values())
#      86 mycursor.execute(insert_query,values)
#      87 mydb.commit()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
video_df
# Out:
#        Channel_Name               Channenl_ID     Video_ID  \
# 0   kamalsharmi1013  UCD4fBiLu_tbf_XH73Pp9vxQ  0ULvKDjke9k
# 1   kamalsharmi1013  UCD4fBiLu_tbf_XH73Pp9vxQ  JXO_GHBNnmI
# 2   kamalsharmi1013  UCD4fBiLu_tbf_XH73Pp9vxQ  gqUZtk8wJ9g
# 3   kamalsharmi1013  UCD4fBiLu_tbf_XH73Pp9vxQ  7uXTbhnCnzI
# 4   kamalsharmi1013  UCD4fBiLu_tbf_XH73Pp9vxQ  Vx6V5mLbvdc
# 5   kamalsharmi1013  UCD4fBiLu_tbf_XH73Pp9vxQ  Oq1YC4O3Jwg
# 6   kamalsharmi1013  UCD4fBiLu_tbf_XH73Pp9vxQ  iqVA-VBMids
# 7   kamalsharmi1013  UCD4fBiLu_tbf_XH73Pp9vxQ  wn9Ohtr_WJs
# 8   kamalsharmi1013  UCD4fBiLu_tbf_XH73Pp9vxQ  tz_X3yyMPoQ
# 9   kamalsharmi1013  UCD4fBiLu_tbf_XH73Pp9vxQ  BhKpfC1z2sk
# 10  kamalsharmi1013  UCD4fBiLu_tbf_XH73Pp9vxQ  xO6BWiaDHUg
# 11  kamalsharmi1013  UCD4fBiLu_tbf_XH73Pp9vxQ  7P9XJMsLG8A
# 12  kamalsharmi1013  UCD4fBiLu_tbf_XH73Pp9vxQ  AEXY432fbeA
# 13  kamalsharmi1013  UCD4fBiLu_tbf_XH73Pp9vxQ  q8laltpuHeE
# 14  kamalsharmi1013  UCD4fBiLu_tbf_XH73Pp9vxQ  m2Y3UbnhEPY
# ...
